# %%
import csv
import pandas as pd
import datetime 
import time
import matplotlib.pyplot as plt
import numpy as np
from numpy.random import randn
import os
from pandas import DataFrame as df
from matplotlib import mlab
from matplotlib import pyplot as plt

# %%
old_df = pd.read_csv('load_and_pv.csv')

# %%
# modified CSV
keep_col = ['utc_date','load_kw']
df = old_df[keep_col]
df.to_csv("load_and_pv.csv", index=False)

# %%
# Finding out the average power consumed across time-slices 
df['date'], df['Time'] = df['utc_date'].str.split(' ', 1).str
df['utc_date'].str.split(' ', 1, expand=True)

df = df.loc[(df['Time'] > '12:00') & (df['Time'] < '12:30')]
# print df

# %%
df['utc_date'] = pd.to_datetime(df['utc_date'])
df['weekday'] = df['utc_date'].dt.dayofweek
df['year'] = df['utc_date'].dt.year

# monday=0 , tuesday=1, wed=2, thu=3, fri=4, sat= 5, sun=6
df = df.loc[(df['weekday'] !=5) & (df['weekday'] !=6)]
df = df.loc[df['year'] == 2014]

# %%
del df['year']
del df['date']
del df['Time']
del df['weekday']
#print df

# %%
df['10-10average'] = df['load_kw'].shift().rolling(10).mean()

# %%
df['3-10average'] = df['load_kw'].shift().rolling(10).apply(lambda x: x[np.argsort(x)[-3:]].mean())

# %%
#plotting graph
plt.style.use('ggplot')
df = pd.DataFrame(randn(261,3), index=df.index, columns=['load_kw', '10-10average', '3-10average'])
df = df.cumsum()
plt.figure(); df.plot(); 
plt.show()
# plt.legend(loc='best')
